# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from datetime import datetime
from matplotlib.pyplot import title
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10, 5)
saved_style_state = matplotlib.rcParams.copy()  # give us a style state to go back to
year_list = ['2020/2021', '2019/2020', '2018/2019', '2017/2018', '2016/2017',
'2015/2016', '2014/2015', '2013/2014', '2012/2013', '2011/2012', '2010/2011',
'2009/2010', '2008/2009', '2007/2008', '2006/2007', '2005/2006', '2004/2005',
'2003/2004', '2002/2003', '2001/2002', '2000/2001', '1999/2000', '1998/1999']

def load_file(year_to_load = "all"):
    if year_to_load == "all":
        load_this = "emissions.csv"
        if os.path.isfile(load_this):
            print(f"loading from file: {load_this}")
            return_dataset = pd.read_csv(load_this)
        else:
            print("Can't find dataset")
    else:
        from_year, to_year = year_to_load.split("/")
        load_this = f"emissions {from_year} to {to_year}.xlsx"
        if os.path.isfile(load_this):
            print(f"loading from file: {load_this}")
            return_dataset = pd.read_excel(load_this)
        else:
            print("Can't find dataset")
    return_rows_of_data = len(return_dataset.index)
    return return_dataset, return_rows_of_data

def unique_items_into_list(data, heading):
    return_list = []
    for item in data[heading]:
        if item not in return_list:
            return_list.append(item)
    return return_list
    
emissions_data, rows_of_data = load_file()
# Out:
# loading from file: emissions.csv

# %%
for x in emissions_data:
    print(x)
# Out:
# report_id
# report_year
# facility_id
# jurisdiction_code
# jurisdiction_facility_id
# facility_name
# registered_business_name
# primary_anzsic_class_code
# primary_anzsic_class_name
# substance_id
# substance_sort_order
# substance_name
# air_point_emission_kg
# air_point_eet
# air_fugitive_emission_kg
# air_fugitive_eet
# air_total_emission_kg
# water_emission_kg
# water_eet
# land_emission_kg
# land_eet
# suburb
# state
# postcode
# latitude
# longitude
# pivot_facility_name

# %%
from matplotlib.pyplot import subplot
#pd.set_option('display.max_columns', None)

list_years = []

list_years = unique_items_into_list(emissions_data, "report_year")
print(f"Rows of data: {rows_of_data}")

df_year_tally = emissions_data['report_year'].value_counts(sort=False)
df_year_tally = pd.DataFrame(df_year_tally)
print(df_year_tally)
df_year_tally.plot(kind = "bar", figsize = (20,20))
# Out:
# Rows of data: 830263
#            report_year
# 2020/2021        42870
# 2019/2020        43478
# 2018/2019        43941
# 2017/2018        43760
# 2016/2017        43165
# 2015/2016        43381
# 2014/2015        42471
# 2013/2014        42538
# 2012/2013        42534
# 2011/2012        41533
# 2010/2011        40257
# 2009/2010        39491
# 2008/2009        39508
# 2007/2008        38918
# 2006/2007        35453
# 2005/2006        35148
# 2004/2005        34117
# 2003/2004        33788
# 2002/2003        32879
# 2001/2002        29251
# 2000/2001        20001
# 1999/2000        15539
# 1998/1999         6242
# <AxesSubplot:>

# %% [markdown]
# Types of emissions

# %%
emissions_data, rows_of_data = load_file("2020/2021")
emissions_data.columns
row_one = emissions_data.iloc[0]
#print(row_one['primary_anzsic_class_name'])

list_substance_name = []
list_substance_name = unique_items_into_list(emissions_data, "substance_name")
print(list_substance_name)
print(len(list_substance_name))
# Out:
# loading from file: emissions 2020 to 2021.xlsx
# ['Ethanol', 'Total Volatile Organic Compounds', 'Ammonia (total)', 'Carbon monoxide', 'Oxides of Nitrogen', 'Particulate Matter ≤2.5 µm (PM2.5)', 'Particulate Matter ≤10.0 µm (PM10)', 'Polycyclic aromatic hydrocarbons (B[a]Peq)', 'Sulfur dioxide', 'Acetone', 'Acetonitrile', 'Acrylonitrile (2-propenenitrile)', 'Antimony & compounds', 'Arsenic & compounds', 'Benzene', 'Beryllium & compounds', 'Cadmium & compounds', 'Carbon disulfide', 'Chlorine & compounds', 'Chloroethane (ethyl chloride)', 'Chloroform (trichloromethane)', 'Chlorophenols (di, tri, tetra)', 'Chromium (III) compounds', 'Chromium (VI) compounds', 'Copper & compounds', 'Cumene (1-methylethylbenzene)', 'Cyclohexane', '1,2-Dichloroethane', 'Dichloromethane', 'Ethyl acetate', 'Ethylbenzene', 'Formaldehyde (methyl aldehyde)', 'n-Hexane', 'Hydrochloric acid', 'Hydrogen sulfide', 'Lead & compounds', 'Mercury & compounds', 'Methyl ethyl ketone', 'Methyl isobutyl ketone', 'Nickel & compounds', 'Phenol', 'Polychlorinated dioxins and furans (TEQ)', 'Styrene (ethenylbenzene)', 'Tetrachloroethylene', 'Toluene (methylbenzene)', '1,1,2-Trichloroethane', 'Trichloroethylene', 'Vinyl Chloride Monomer', 'Xylenes (individual or mixed isomers)', 'Zinc and compounds', 'Cobalt & compounds', 'Manganese & compounds', 'Selenium & compounds', 'Fluoride compounds', 'Boron & compounds', 'Acetic acid (ethanoic acid)', 'Methanol', 'Cyanide (inorganic) compounds', '1,3-Butadiene (vinyl ethylene)', 'Magnesium oxide fume', 'Total Nitrogen', 'Total Phosphorus', 'Sulfuric acid', 'Toluene-2,4-diisocyanate', 'Acetaldehyde', 'Ethylene glycol (1,2-ethanediol)', 'Acrylic acid', 'Methyl methacrylate', '1,2-Dibromoethane', 'Biphenyl (1,1-biphenyl)', 'Acrolein', 'Dibutyl phthalate', 'Nitric acid', 'Nickel subsulfide', 'Methylenebis (phenylisocyanate)', 'Phosphoric acid', 'Glutaraldehyde', 'Acrylamide', 'Ethylene oxide', 'Organo-tin compounds', 'Chlorine dioxide', '2-Ethoxyethanol', 'Di-(2-Ethylhexyl) phthalate (DEHP)']
# 83

# %% [markdown]
# Frequency Of Emission

# %%
from matplotlib.pyplot import subplot

#pd.set_option('display.max_columns', None)
#print(emissions_data['substance_name'].value_counts())

substance_tally = emissions_data['substance_name'].value_counts(sort=True)
df_substance_tally = pd.DataFrame(substance_tally)
print(df_substance_tally)
top_df_substance_tally = df_substance_tally.nlargest(20, "substance_name")
top_df_substance_tally.plot(kind = "barh", figsize = (20,8))
#pd.DataFrame(substance_tally)
# Out:
#                                     substance_name
# Total Volatile Organic Compounds              3302
# Carbon monoxide                               2077
# Sulfur dioxide                                2055
# Oxides of Nitrogen                            2053
# Particulate Matter ≤10.0 µm (PM10)            2053
# ...                                            ...
# Chlorine dioxide                                 2
# Nickel subsulfide                                2
# Dibutyl phthalate                                1
# 2-Ethoxyethanol                                  1
# Di-(2-Ethylhexyl) phthalate (DEHP)               1
#
# [83 rows x 1 columns]
# <AxesSubplot:>

# %% [markdown]
# Amount Of Emission

# %%
def total_emission(data_of_row):
    total = 0
    if not pd.isna(data_of_row["air_total_emission_kg"]):
        total += data_of_row["air_total_emission_kg"]
    if not pd.isna(data_of_row["water_emission_kg"]):
        total += data_of_row["water_emission_kg"]
    if not pd.isna(data_of_row["land_emission_kg"]):
        total += data_of_row["land_emission_kg"]
    #print(total)
    return total

small = 1
list_emission_amount = []
dict_amount_of_emission = {}
df_substances_by_emission_amount = {}

emissions_data, rows_of_data = load_file("2020/2021")

for substance in list_substance_name:
    dict_amount_of_emission[substance] = []
#print(dict_amount_of_emission)

for row in range(0, rows_of_data):
    data_of_row = emissions_data.iloc[row]
    append_total_emission = total_emission(data_of_row)
    dict_amount_of_emission[data_of_row["substance_name"]].append(append_total_emission)
    
    #Finding smallest recorded substance
    if append_total_emission < small:
        small = append_total_emission
        source = data_of_row["substance_name"]
        report = data_of_row["report_id"]
print(source, small, report)


for substance in dict_amount_of_emission:
    dict_amount_of_emission[substance] = sum(dict_amount_of_emission[substance])
    list_emission_amount.append(dict_amount_of_emission[substance])

#print(dict_amount_of_emission)
df_substances_by_emission_amount["Substance"] = list_substance_name
df_substances_by_emission_amount["Emission Amount"] = list_emission_amount

pd.options.display.float_format = '{:20,.2f}'.format

df_substances_by_emission_amount=pd.DataFrame(df_substances_by_emission_amount)
df_sort = df_substances_by_emission_amount.sort_values(by="Emission Amount", ascending=False)
top_df_sort = df_sort.nlargest(10, "Emission Amount")
print(top_df_sort)
#is_top = df_sort["Average"] >= 20000
top_df_sort.plot(x ="Substance", y="Emission Amount", kind = "bar", figsize=(20,15))
plt.title("Substances By Emissions Amount")
plt.xlabel("Emission Amount")
plt.ylabel("Substance")
# Out:
# loading from file: emissions 2020 to 2021.xlsx
# Chromium (VI) compounds 4.396e-17 523696
#                              Substance      Emission Amount
# 6   Particulate Matter ≤10.0 µm (PM10)     1,223,925,027.29
# 8                       Sulfur dioxide       973,088,155.39
# 3                      Carbon monoxide       744,673,023.69
# 4                   Oxides of Nitrogen       714,243,986.35
# 1     Total Volatile Organic Compounds        99,622,343.68
# 2                      Ammonia (total)        76,382,701.26
# 60                      Total Nitrogen        38,772,891.12
# 5   Particulate Matter ≤2.5 µm (PM2.5)        28,538,977.70
# 33                   Hydrochloric acid        27,145,025.62
# 53                  Fluoride compounds         8,836,896.81
# Text(0, 0.5, 'Substance')

# %%
def filter_function(word, list_keywords):
    if word in list_keywords:
        return True
    else:
        return False

def get_substance_info(year):
    list_emission_amount = []
    dict_amount_of_emission = {}
    emissions_data, rows_of_data = load_file(year)

    for substance in list_substance_name:
        if filter_function(substance, list_keywords):
            dict_amount_of_emission[substance] = []

    for row in range(0, rows_of_data):
        data_of_row = emissions_data.iloc[row]
        if filter_function(data_of_row["substance_name"], list_keywords):
            append_total_emission = total_emission(data_of_row)
            dict_amount_of_emission[data_of_row["substance_name"]].append(append_total_emission)

    for substance in dict_amount_of_emission:
        dict_amount_of_emission[substance] = sum(dict_amount_of_emission[substance])
        list_emission_amount.append(dict_amount_of_emission[substance])
    return list_emission_amount

list_keywords = ["Particulate Matter ≤10.0 µm (PM10)", "Sulfur dioxide", "Carbon monoxide", "Oxides of Nitrogen",
"Total Volatile Organic Compounds", "Ammonia (total)", "Total Nitrogen", "Particulate Matter ≤2.5 µm (PM2.5)", "Hydrochloric acid", 
"Fluoride compounds"]

df_substances_by_emission_amount_2020 = get_substance_info("2020/2021")
df_substances_by_emission_amount_2015 = get_substance_info("2015/2016")
df_substances_by_emission_amount_2010 = get_substance_info("2010/2011")
df_substances_by_emission_amount_2005 = get_substance_info("2005/2006")
# Out:
# loading from file: emissions 2020 to 2021.xlsx
# loading from file: emissions 2015 to 2016.xlsx
# loading from file: emissions 2010 to 2011.xlsx
# loading from file: emissions 2005 to 2006.xlsx

# %%
df_substances_by_emission_amount=pd.DataFrame({
    "Emission Amount 2005":df_substances_by_emission_amount_2005,
    "Emission Amount 2010":df_substances_by_emission_amount_2010,
    "Emission Amount 2015":df_substances_by_emission_amount_2015,
    "Emission Amount 2020":df_substances_by_emission_amount_2020,
    }, 
    index=list_keywords
)

pd.options.display.float_format = '{:20,.2f}'.format

df_sort = df_substances_by_emission_amount.sort_values(by="Emission Amount 2020", ascending=False)
df_sort.plot(kind = "bar", figsize=(20,15))
plt.title("Substances By Emissions Amount")
plt.xlabel("Substance")
plt.ylabel("Emission Amount")
# Out:
# Text(0, 0.5, 'Emission Amount')

# %% [markdown]
# Ammonia is used widely in many areas. It is present in commonly used household and industrial cleaners, bleaching agents and disinfectants. It is used in the preparation of synthetic fibres (e.g. nylons), plastics and explosives, resins, human and veterinary medicines, fertilisers, chemical compounds, fuel cells, rocket fuel, dyes, metal treating operations, refrigeration, and in the petroleum industry. -From National Pollutant Index

# %% [markdown]
# Smallest recorded: Chromium (VI) compounds 0.00000000000000004396kg 0.00000000000004396g
#
# Least used substance: Polychlorinated dioxins and furans (TEQ) 0.04kg

# %% [markdown]
# Industries That Produce Emissions

# %%
list_industry = unique_items_into_list(emissions_data, "primary_anzsic_class_name")
for industry in list_industry:
    print(industry)
print(len(list_industry))
# Out:
# Wine and Other Alcoholic Beverage Manufacturing
# Beer Manufacturing
# Beef Cattle Feedlots (Specialised)
# Waste Treatment and Disposal Services
# Meat Processing
# Pig Farming
# Other Petroleum and Coal Product Manufacturing
# Port and Water Transport Terminal Operations
# Milk and Cream Processing
# Gold Ore Mining
# Coal Mining
# Basic Inorganic Chemical Manufacturing
# Cement and Lime Manufacturing
# Other Non-Metallic Mineral Mining and Quarrying
# Other Construction Material Mining
# Metal Coating and Finishing
# Water Supply
# Polymer Foam Product Manufacturing
# Gas Supply
# Oil and Gas Extraction
# Fossil Fuel Electricity Generation
# Petroleum Refining and Petroleum Fuel Manufacturing
# Fertiliser Manufacturing
# Industrial Gas Manufacturing
# Other Professional and Scientific Equipment Manufacturing
# Natural Rubber Product Manufacturing
# Log Sawmilling
# Paint and Coatings Manufacturing
# Basic Organic Chemical Manufacturing
# Sewerage and Drainage Services
# Bauxite Mining
# Alumina Production
# Aluminium Smelting
# Printing
# Hospitals (Except Psychiatric Hospitals)
# Iron Smelting and Steel Manufacturing
# Other Basic Chemical Product Manufacturing n.e.c.
# Human Pharmaceutical and Medicinal Product Manufacturing
# Reconstituted Wood Product Manufacturing
# Laundry and Dry-Cleaning Services
# Polymer Film and Sheet Packaging Material Manufacturing
# Industrial and Agricultural Chemical Product Wholesaling
# Other Polymer Product Manufacturing
# Petroleum Product Wholesaling
# Rigid and Semi-Rigid Polymer Product Manufacturing
# Biscuit Manufacturing (Factory based)
# Bread Manufacturing (Factory based)
# Soft Drink, Cordial and Syrup Manufacturing
# Other Fabricated Metal Product Manufacturing n.e.c.
# Oil and Fat Manufacturing
# Iron Ore Mining
# Textile Finishing and Other Textile Product Manufacturing
# Rail Freight Transport
# Silver-Lead-Zinc Ore Mining
# Copper Ore Mining
# Other Non-Metallic Mineral Product Manufacturing
# Clay Brick Manufacturing
# Veneer and Plywood Manufacturing
# Ice Cream Manufacturing
# Airport Operations and Other Air Transport Support Services
# Railway Rolling Stock Manufacturing and Repair Services
# Other Food Product Manufacturing n.e.c.
# Cereal, Pasta and Baking Mix Manufacturing
# Higher Education
# Nickel Ore Mining
# Other Warehousing and Storage Services
# Shipbuilding and Repair Services
# Poultry Farming (Meat)
# Poultry Farming (Eggs)
# Poultry Processing
# Tyre Manufacturing
# Grain Mill Product Manufacturing
# Gravel and Sand Quarrying
# Prepared Animal and Bird Feed Manufacturing
# Cheese and Other Dairy Product Manufacturing
# Spring and Wire Product Manufacturing
# Waste Remediation and Materials Recovery Services
# Concrete Product Manufacturing
# Other Basic Non-Ferrous Metal Manufacturing
# Iron and Steel Casting
# Other Metal Ore Mining
# Aircraft Manufacturing and Repair Services
# Other Ceramic Product Manufacturing
# Adhesive Manufacturing
# Urban Bus Transport (Including Tramway)
# Timber Resawing and Dressing
# Confectionery Manufacturing
# Spirit Manufacturing
# Sugar Manufacturing
# Wood Chipping
# Copper, Silver, Lead and Zinc Smelting and Refining
# Fruit and Vegetable Processing
# Other Electricity Generation
# Aluminium Rolling, Drawing, Extruding
# Funeral, Crematorium and Cemetery Services
# Other Electrical Equipment Manufacturing
# Cleaning Compound Manufacturing
# Explosive Manufacturing
# Mineral Sand Mining
# Scientific Research Services
# Glass and Glass Product Manufacturing
# Other Basic Non-Ferrous Metal Product Manufacturing
# Plaster Product Manufacturing
# Structural Steel Fabricating
# Other Transport Support Services n.e.c.
# Stevedoring Services
# Wool Scouring
# Whiteware Appliance Manufacturing
# Pulp, Paper and Paperboard Manufacturing
# Solid Waste Collection Services
# Other Motor Vehicle Parts Manufacturing
# Synthetic Resin and Synthetic Rubber Manufacturing
# Leather Tanning, Fur Dressing and Leather Product Manufacturing
# Non-Ferrous Metal Casting
# Cured Meat and Smallgoods Manufacturing
# Textile Floor Covering Manufacturing
# Other Metal Container Manufacturing
# Other Wood Product Manufacturing n.e.c.
# Other Basic Polymer Manufacturing
# Ready-Mixed Concrete Manufacturing
# Other Structural Metal Product Manufacturing
# Nut, Bolt, Screw and Rivet Manufacturing
# Cosmetic and Toiletry Preparation Manufacturing
# Beef Cattle Farming (Specialised)
# Other Converted Paper Product Manufacturing
# Medical and Surgical Equipment Manufacturing
# Boiler, Tank and Other Heavy Gauge Metal Container Manufacturing
# Cake and Pastry Manufacturing (Factory based)
# Mining and Construction Machinery Manufacturing
# Data Processing and Web Hosting Services
# Other Waste Collection Services
# Pesticide Manufacturing
# Steel Pipe and Tube Manufacturing
# Corrugated Paperboard and Paperboard Container Manufacturing
# Iron and Steel Forging
# Motor Vehicle Manufacturing
# Seafood Processing
# Electric Cable and Wire Manufacturing
# Other Transport n.e.c.
# Road Freight Transport
# Rail Passenger Transport
# Hydro-Electricity Generation
# Potato, Corn and Other Crisp Manufacturing
# Water Passenger Transport
# 144

# %% [markdown]
# Gas Supply\
# Oil and Gas Extraction\
# Fossil Fuel Electricity Generation\
# Petroleum Refining and Petroleum Fuel Manufacturing\
# Industrial Gas Manufacturing\
# Petroleum Product Wholesaling\

# %% [markdown]
# Biscuit Manufacturing (Factory based)\
# Bread Manufacturing (Factory based)\
# Higher Education\
# Data Processing and Web Hosting Services\

# %%
list_emission_amount = []
dict_amount_of_emission_by_industry = {}
df_industries_by_emission_amount = {}

emissions_data, rows_of_data = load_file("2020/2021")

list_industry = unique_items_into_list(emissions_data, "primary_anzsic_class_name")
for industry in list_industry:
    dict_amount_of_emission_by_industry[industry] = []
#print(dict_amount_of_emission_by_industry)

for row in range(0, rows_of_data):
    data_of_row = emissions_data.iloc[row]
    append_total_emission = total_emission(data_of_row)
    dict_amount_of_emission_by_industry[data_of_row["primary_anzsic_class_name"]].append(append_total_emission)

for industry in dict_amount_of_emission_by_industry:
    dict_amount_of_emission_by_industry[industry] = sum(dict_amount_of_emission_by_industry[industry])
    list_emission_amount.append(dict_amount_of_emission_by_industry[industry])

#print(dict_amount_of_emission_by_industry)
df_industries_by_emission_amount["Industry"] = list_industry
df_industries_by_emission_amount["Emission Amount"] = list_emission_amount
# Out:
# loading from file: emissions 2020 to 2021.xlsx

# %%
pd.options.display.float_format = '{:20,.2f}'.format

df_industries_by_emission_amount=pd.DataFrame(df_industries_by_emission_amount)
df_sort = df_industries_by_emission_amount.sort_values(by="Emission Amount", ascending=False)
top_df_sort = df_sort.nlargest(20, "Emission Amount")
print(top_df_sort)
top_df_sort.plot(x ="Industry", y="Emission Amount", kind = "bar", figsize=(20,15))
plt.title("Industries By Emissions Amount")
plt.xlabel("Emission Amount")
plt.ylabel("industry")
# Out:
#                                               Industry      Emission Amount
# 20                  Fossil Fuel Electricity Generation       831,812,456.91
# 10                                         Coal Mining       463,264,451.86
# 50                                     Iron Ore Mining       458,161,202.78
# 90   Copper, Silver, Lead and Zinc Smelting and Ref...       422,813,976.28
# 35               Iron Smelting and Steel Manufacturing       258,269,525.73
# ..                                                 ...                  ...
# 110            Other Motor Vehicle Parts Manufacturing           114,533.20
# 96                     Cleaning Compound Manufacturing           110,652.81
# 129           Data Processing and Web Hosting Services           105,471.94
# 112  Leather Tanning, Fur Dressing and Leather Prod...           100,613.42
# 86                         Confectionery Manufacturing            85,562.11
#
# [100 rows x 2 columns]
# Text(0, 0.5, 'industry')

# %%
emissions_data, rows_of_data = load_file("2020/2021")
# Out:
# loading from file: emissions 2020 to 2021.xlsx

# %%
list_emission_amount = []
list_business = []
dict_amount_of_emission_by_industry = {}
dict_industries_by_business_amount = {}
dict_amount_of_emission_by_industry_average = {}
df_industries_by_emission_amount_average = {}
dict_industries_by_different_substances = {}

list_industry = unique_items_into_list(emissions_data, "primary_anzsic_class_name")
for industry in list_industry:
    dict_amount_of_emission_by_industry[industry] = []
    dict_industries_by_business_amount[industry] = []
    dict_industries_by_different_substances[industry] = []

for row in range(0, rows_of_data):
    data_of_row = emissions_data.iloc[row]
    append_total_emission = total_emission(data_of_row)
    dict_amount_of_emission_by_industry[data_of_row["primary_anzsic_class_name"]].append(append_total_emission)
    if data_of_row["registered_business_name"] not in dict_industries_by_business_amount[data_of_row["primary_anzsic_class_name"]]:
        dict_industries_by_business_amount[data_of_row["primary_anzsic_class_name"]].append(data_of_row["registered_business_name"])
    
    if data_of_row["substance_name"] not in dict_industries_by_different_substances[data_of_row["primary_anzsic_class_name"]]:
        #if data_of_row["primary_anzsic_class_name"] == "Dairy Cattle Farming":
            #print(data_of_row["report_id"])
        dict_industries_by_different_substances[data_of_row["primary_anzsic_class_name"]].append(data_of_row["substance_name"])

for x in dict_industries_by_different_substances:
    print(f"{x} {len(dict_industries_by_different_substances[x])}")

#print(dict_industries_by_different_substances["Dairy Cattle Farming"])

#print(dict_industries_by_different_substances)
# Out:
# Wine and Other Alcoholic Beverage Manufacturing 20
# Beer Manufacturing 41
# Beef Cattle Feedlots (Specialised) 34
# Waste Treatment and Disposal Services 60
# Meat Processing 38
# Pig Farming 18
# Other Petroleum and Coal Product Manufacturing 38
# Port and Water Transport Terminal Operations 39
# Milk and Cream Processing 33
# Gold Ore Mining 39
# Coal Mining 43
# Basic Inorganic Chemical Manufacturing 52
# Cement and Lime Manufacturing 32
# Other Non-Metallic Mineral Mining and Quarrying 35
# Other Construction Material Mining 25
# Metal Coating and Finishing 33
# Water Supply 20
# Polymer Foam Product Manufacturing 23
# Gas Supply 37
# Oil and Gas Extraction 40
# Fossil Fuel Electricity Generation 49
# Petroleum Refining and Petroleum Fuel Manufacturing 47
# Fertiliser Manufacturing 38
# Industrial Gas Manufacturing 29
# Other Professional and Scientific Equipment Manufacturing 2
# Natural Rubber Product Manufacturing 6
# Log Sawmilling 31
# Paint and Coatings Manufacturing 32
# Basic Organic Chemical Manufacturing 53
# Sewerage and Drainage Services 35
# Bauxite Mining 36
# Alumina Production 40
# Aluminium Smelting 30
# Printing 23
# Hospitals (Except Psychiatric Hospitals) 43
# Iron Smelting and Steel Manufacturing 49
# Other Basic Chemical Product Manufacturing n.e.c. 52
# Human Pharmaceutical and Medicinal Product Manufacturing 40
# Reconstituted Wood Product Manufacturing 35
# Laundry and Dry-Cleaning Services 25
# Polymer Film and Sheet Packaging Material Manufacturing 22
# Industrial and Agricultural Chemical Product Wholesaling 21
# Other Polymer Product Manufacturing 13
# Petroleum Product Wholesaling 39
# Rigid and Semi-Rigid Polymer Product Manufacturing 26
# Biscuit Manufacturing (Factory based) 26
# Bread Manufacturing (Factory based) 17
# Soft Drink, Cordial and Syrup Manufacturing 21
# Other Fabricated Metal Product Manufacturing n.e.c. 5
# Oil and Fat Manufacturing 30
# Iron Ore Mining 39
# Textile Finishing and Other Textile Product Manufacturing 16
# Rail Freight Transport 28
# Silver-Lead-Zinc Ore Mining 35
# Copper Ore Mining 40
# Other Non-Metallic Mineral Product Manufacturing 29
# Clay Brick Manufacturing 24
# Veneer and Plywood Manufacturing 20
# Ice Cream Manufacturing 17
# Airport Operations and Other Air Transport Support Services 27
# Railway Rolling Stock Manufacturing and Repair Services 33
# Other Food Product Manufacturing n.e.c. 40
# Cereal, Pasta and Baking Mix Manufacturing 20
# Higher Education 22
# Nickel Ore Mining 36
# Other Warehousing and Storage Services 37
# Shipbuilding and Repair Services 2
# Poultry Farming (Meat) 10
# Poultry Farming (Eggs) 1
# Poultry Processing 24
# Tyre Manufacturing 43
# Grain Mill Product Manufacturing 27
# Gravel and Sand Quarrying 30
# Prepared Animal and Bird Feed Manufacturing 27
# Cheese and Other Dairy Product Manufacturing 23
# Spring and Wire Product Manufacturing 27
# Waste Remediation and Materials Recovery Services 28
# Concrete Product Manufacturing 21
# Other Basic Non-Ferrous Metal Manufacturing 37
# Iron and Steel Casting 34
# Other Metal Ore Mining 41
# Aircraft Manufacturing and Repair Services 25
# Other Ceramic Product Manufacturing 22
# Adhesive Manufacturing 8
# Urban Bus Transport (Including Tramway) 3
# Timber Resawing and Dressing 18
# Confectionery Manufacturing 23
# Spirit Manufacturing 25
# Sugar Manufacturing 35
# Wood Chipping 8
# Copper, Silver, Lead and Zinc Smelting and Refining 36
# Fruit and Vegetable Processing 21
# Other Electricity Generation 20
# Aluminium Rolling, Drawing, Extruding 22
# Funeral, Crematorium and Cemetery Services 10
# Other Electrical Equipment Manufacturing 22
# Cleaning Compound Manufacturing 26
# Explosive Manufacturing 37
# Mineral Sand Mining 35
# Scientific Research Services 9
# Glass and Glass Product Manufacturing 27
# Other Basic Non-Ferrous Metal Product Manufacturing 2
# Plaster Product Manufacturing 23
# Structural Steel Fabricating 9
# Other Transport Support Services n.e.c. 7
# Stevedoring Services 26
# Wool Scouring 20
# Whiteware Appliance Manufacturing 9
# Pulp, Paper and Paperboard Manufacturing 44
# Solid Waste Collection Services 10
# Other Motor Vehicle Parts Manufacturing 13
# Synthetic Resin and Synthetic Rubber Manufacturing 33
# Leather Tanning, Fur Dressing and Leather Product Manufacturing 12
# Non-Ferrous Metal Casting 9
# Cured Meat and Smallgoods Manufacturing 22
# Textile Floor Covering Manufacturing 7
# Other Metal Container Manufacturing 23
# Other Wood Product Manufacturing n.e.c. 31
# Other Basic Polymer Manufacturing 14
# Ready-Mixed Concrete Manufacturing 7
# Other Structural Metal Product Manufacturing 20
# Nut, Bolt, Screw and Rivet Manufacturing 8
# Cosmetic and Toiletry Preparation Manufacturing 22
# Beef Cattle Farming (Specialised) 2
# Other Converted Paper Product Manufacturing 7
# Medical and Surgical Equipment Manufacturing 9
# Boiler, Tank and Other Heavy Gauge Metal Container Manufacturing 1
# Cake and Pastry Manufacturing (Factory based) 20
# Mining and Construction Machinery Manufacturing 2
# Data Processing and Web Hosting Services 7
# Other Waste Collection Services 3
# Pesticide Manufacturing 24
# Steel Pipe and Tube Manufacturing 17
# Corrugated Paperboard and Paperboard Container Manufacturing 18
# Iron and Steel Forging 20
# Motor Vehicle Manufacturing 10
# Seafood Processing 8
# Electric Cable and Wire Manufacturing 8
# Other Transport n.e.c. 3
# Road Freight Transport 2
# Rail Passenger Transport 5
# Hydro-Electricity Generation 7
# Potato, Corn and Other Crisp Manufacturing 16
# Water Passenger Transport 7

# %%
list_industry = []

for industry in dict_amount_of_emission_by_industry:
    dict_industries_by_business_amount[industry] = len(dict_industries_by_business_amount[industry])
    dict_amount_of_emission_by_industry_average[industry] = sum(dict_amount_of_emission_by_industry[industry])/dict_industries_by_business_amount[industry]
    #print(dict_amount_of_emission_by_industry_average[industry])
    list_industry.append(industry)
    list_emission_amount.append(dict_amount_of_emission_by_industry_average[industry])

df_industries_by_emission_amount_average["Industry"] = list_industry
df_industries_by_emission_amount_average["Emission Amount"] = list_emission_amount

pd.options.display.float_format = '{:20,.2f}'.format
pd.set_option('display.max_rows', 200)

df_industries_by_emission_amount_average=pd.DataFrame(df_industries_by_emission_amount_average)
df_sort = df_industries_by_emission_amount_average.sort_values(by="Emission Amount", ascending=False)
top_df_sort = df_sort.nlargest(1000, "Emission Amount")
print(top_df_sort)
top_df_sort = df_sort.nlargest(10, "Emission Amount")
top_df_sort.plot(x ="Industry", y="Emission Amount", kind = "bar", figsize=(20,15))
plt.title("Industries By Emissions Amount")
plt.xlabel("Emission Amount")
plt.ylabel("industry")
# Out:
#                                               Industry      Emission Amount
# 90   Copper, Silver, Lead and Zinc Smelting and Ref...        42,281,397.63
# 32                                  Aluminium Smelting        35,721,169.94
# 35               Iron Smelting and Steel Manufacturing        32,283,690.72
# 50                                     Iron Ore Mining        20,825,509.22
# 31                                  Alumina Production        15,704,757.82
# 20                  Fossil Fuel Electricity Generation        10,021,836.83
# 30                                      Bauxite Mining         7,955,286.24
# 19                              Oil and Gas Extraction         6,478,565.66
# 39                   Laundry and Dry-Cleaning Services         6,155,091.39
# 10                                         Coal Mining         5,649,566.49
# 64                                   Nickel Ore Mining         4,792,375.20
# 13     Other Non-Metallic Mineral Mining and Quarrying         4,314,389.90
# 78         Other Basic Non-Ferrous Metal Manufacturing         3,986,654.97
# 9                                      Gold Ore Mining         3,832,165.62
# 22                            Fertiliser Manufacturing         3,143,601.40
# 80                              Other Metal Ore Mining         3,134,388.47
# 21   Petroleum Refining and Petroleum Fuel Manufact...         3,042,748.75
# 88                                 Sugar Manufacturing         2,432,259.46
# 54                                   Copper Ore Mining         2,293,538.30
# 98                                 Mineral Sand Mining         2,019,415.50
# 12                       Cement and Lime Manufacturing         1,527,685.95
# 53                         Silver-Lead-Zinc Ore Mining         1,521,616.26
# 100              Glass and Glass Product Manufacturing         1,073,287.17
# 29                      Sewerage and Drainage Services         1,072,975.41
# 7         Port and Water Transport Terminal Operations           803,013.06
# 92                        Other Electricity Generation           754,728.91
# 23                        Industrial Gas Manufacturing           740,979.81
# 11              Basic Inorganic Chemical Manufacturing           733,059.65
# 2                   Beef Cattle Feedlots (Specialised)           687,450.25
# 45               Biscuit Manufacturing (Factory based)           635,781.07
# 70                                  Tyre Manufacturing           628,818.75
# 108           Pulp, Paper and Paperboard Manufacturing           597,461.00
# 56                            Clay Brick Manufacturing           596,385.92
# 143                          Water Passenger Transport           551,042.07
# 72                           Gravel and Sand Quarrying           527,898.60
# 97                             Explosive Manufacturing           460,066.66
# 57                    Veneer and Plywood Manufacturing           430,874.20
# 14                  Other Construction Material Mining           396,421.48
# 102                      Plaster Product Manufacturing           384,251.34
# 60   Railway Rolling Stock Manufacturing and Repair...           337,019.56
# 76   Waste Remediation and Materials Recovery Services           326,362.49
# 38            Reconstituted Wood Product Manufacturing           293,981.04
# 40   Polymer Film and Sheet Packaging Material Manu...           280,105.14
# 59   Airport Operations and Other Air Transport Sup...           272,470.34
# 79                              Iron and Steel Casting           259,182.40
# 111  Synthetic Resin and Synthetic Rubber Manufactu...           248,196.98
# 116                Other Metal Container Manufacturing           236,179.56
# 120       Other Structural Metal Product Manufacturing           216,565.67
# 18                                          Gas Supply           204,815.22
# 117            Other Wood Product Manufacturing n.e.c.           202,693.83
# 16                                        Water Supply           200,041.99
# 46                 Bread Manufacturing (Factory based)           166,606.43
# 26                                      Log Sawmilling           164,992.15
# 89                                       Wood Chipping           162,765.94
# 61             Other Food Product Manufacturing n.e.c.           162,750.15
# 5                                          Pig Farming           160,826.02
# 33                                            Printing           160,696.57
# 85                        Timber Resawing and Dressing           157,858.13
# 91                      Fruit and Vegetable Processing           152,250.37
# 135                        Motor Vehicle Manufacturing           151,584.16
# 55    Other Non-Metallic Mineral Product Manufacturing           138,345.86
# 6       Other Petroleum and Coal Product Manufacturing           134,391.06
# 52                              Rail Freight Transport           131,822.57
# 87                                Spirit Manufacturing           130,675.10
# 133  Corrugated Paperboard and Paperboard Container...           118,044.12
# 67                              Poultry Farming (Meat)           106,551.87
# 129           Data Processing and Web Hosting Services           105,471.94
# 68                              Poultry Farming (Eggs)           101,648.89
# 28                Basic Organic Chemical Manufacturing            98,941.16
# 65              Other Warehousing and Storage Services            96,001.66
# 4                                      Meat Processing            95,648.08
# 71                    Grain Mill Product Manufacturing            87,571.64
# 37   Human Pharmaceutical and Medicinal Product Man...            80,845.60
# 17                  Polymer Foam Product Manufacturing            79,058.34
# 81          Aircraft Manufacturing and Repair Services            75,059.66
# 77                      Concrete Product Manufacturing            64,773.96
# 47         Soft Drink, Cordial and Syrup Manufacturing            61,823.07
# 44   Rigid and Semi-Rigid Polymer Product Manufactu...            56,986.00
# 15                         Metal Coating and Finishing            56,328.51
# 105                               Stevedoring Services            55,182.51
# 69                                  Poultry Processing            53,875.71
# 82                 Other Ceramic Product Manufacturing            51,519.46
# 66                    Shipbuilding and Repair Services            51,000.00
# 3                Waste Treatment and Disposal Services            49,927.93
# 73         Prepared Animal and Bird Feed Manufacturing            45,116.70
# 27                    Paint and Coatings Manufacturing            43,049.98
# 42                 Other Polymer Product Manufacturing            41,163.72
# 123                  Beef Cattle Farming (Specialised)            39,755.22
# 8                            Milk and Cream Processing            38,857.92
# 110            Other Motor Vehicle Parts Manufacturing            38,177.73
# 49                           Oil and Fat Manufacturing            36,154.00
# 74        Cheese and Other Dairy Product Manufacturing            36,121.87
# 43                       Petroleum Product Wholesaling            36,101.73
# 1                                   Beer Manufacturing            34,223.64
# 141                       Hydro-Electricity Generation            28,145.71
# 131                            Pesticide Manufacturing            26,256.96
# 142         Potato, Corn and Other Crisp Manufacturing            26,247.91
# 112  Leather Tanning, Fur Dressing and Leather Prod...            25,153.36
# 114            Cured Meat and Smallgoods Manufacturing            24,518.19
# 109                    Solid Waste Collection Services            24,231.06
# 93               Aluminium Rolling, Drawing, Extruding            22,423.79
# 0      Wine and Other Alcoholic Beverage Manufacturing            22,219.66
# 41   Industrial and Agricultural Chemical Product W...            21,528.26
# 128    Mining and Construction Machinery Manufacturing            19,547.08
# 58                             Ice Cream Manufacturing            19,375.53
# 99                        Scientific Research Services            17,640.75
# 34            Hospitals (Except Psychiatric Hospitals)            16,074.79
# 75               Spring and Wire Product Manufacturing            14,447.27
# 86                         Confectionery Manufacturing            14,260.35
# 83                              Adhesive Manufacturing            14,142.89
# 62          Cereal, Pasta and Baking Mix Manufacturing            13,279.71
# 63                                    Higher Education            12,765.60
# 119                 Ready-Mixed Concrete Manufacturing            12,681.25
# 104            Other Transport Support Services n.e.c.            12,564.32
# 96                     Cleaning Compound Manufacturing            12,294.76
# 121           Nut, Bolt, Screw and Rivet Manufacturing            12,060.24
# 95            Other Electrical Equipment Manufacturing            11,586.47
# 36   Other Basic Chemical Product Manufacturing n.e.c.            10,624.53
# 134                             Iron and Steel Forging            10,403.30
# 107                  Whiteware Appliance Manufacturing             7,652.08
# 106                                      Wool Scouring             7,116.77
# 124        Other Converted Paper Product Manufacturing             6,598.23
# 115               Textile Floor Covering Manufacturing             5,989.49
# 94          Funeral, Crematorium and Cemetery Services             5,466.44
# 136                                 Seafood Processing             4,843.66
# 132                  Steel Pipe and Tube Manufacturing             4,224.33
# 51   Textile Finishing and Other Textile Product Ma...             3,710.73
# 118                  Other Basic Polymer Manufacturing             3,526.75
# 125       Medical and Surgical Equipment Manufacturing             3,254.99
# 25                Natural Rubber Product Manufacturing             3,213.00
# 137              Electric Cable and Wire Manufacturing             2,590.70
# 127      Cake and Pastry Manufacturing (Factory based)             2,241.72
# 122    Cosmetic and Toiletry Preparation Manufacturing             1,744.78
# 113                          Non-Ferrous Metal Casting             1,422.35
# 130                    Other Waste Collection Services             1,368.95
# 103                       Structural Steel Fabricating             1,304.76
# 140                           Rail Passenger Transport             1,298.86
# 84             Urban Bus Transport (Including Tramway)               538.01
# 138                             Other Transport n.e.c.               325.34
# 48   Other Fabricated Metal Product Manufacturing n...                40.01
# 139                             Road Freight Transport                17.07
# 126  Boiler, Tank and Other Heavy Gauge Metal Conta...                 3.60
# 24   Other Professional and Scientific Equipment Ma...                 0.88
# 101  Other Basic Non-Ferrous Metal Product Manufact...                 0.33
# Text(0, 0.5, 'industry')

# %% [markdown]
# Global Warming Potential

# %%
list_emission_amount = []
dict_amount_of_emission_by_industry = {}
df_industries_by_emission_amount = {}

emissions_data, rows_of_data = load_file("2005/2006")

list_industry = unique_items_into_list(emissions_data, "primary_anzsic_class_name")
for industry in list_industry:
    dict_amount_of_emission_by_industry[industry] = []
#print(dict_amount_of_emission_by_industry)

for row in range(0, rows_of_data):
    data_of_row = emissions_data.iloc[row]
    append_total_emission = total_emission(data_of_row)
    dict_amount_of_emission_by_industry[data_of_row["primary_anzsic_class_name"]].append(append_total_emission)

for industry in dict_amount_of_emission_by_industry:
    dict_amount_of_emission_by_industry[industry] = sum(dict_amount_of_emission_by_industry[industry])
    list_emission_amount.append(dict_amount_of_emission_by_industry[industry])

#print(dict_amount_of_emission_by_industry)
df_industries_by_emission_amount["Industry"] = list_industry
df_industries_by_emission_amount["Emission Amount"] = list_emission_amount
